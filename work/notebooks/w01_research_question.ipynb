# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arisckm/vigilant-system/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Selected Lane: Lane 2 — Refresh / Content Opportunity Scoring
#
# Why this lane: I chose this lane because prioritizing which pages need an update or a content refresh is one of the most practical challenges in SEO. Building a data-backed review queue helps editorial teams focus their limited time where it matters most, rather than guessing blindly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Unit of Analysis: A single content page (content_id).
#
# The Decision: Which pages should be flagged for priority review and refreshing?
#
# The Human Action: An editor or content manager pulls the top-ranked pages from the review queue to update facts, expand thin sections, or improve keyword alignment.
#
# Cost of a Wrong Call: If the model is wrong, editors waste time reviewing a page that was already stable or recovering on its own, or conversely, a declining page gets ignored and loses visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset directly from your repository's raw URL
url = "https://raw.githubusercontent.com/arisckm/vigilant-system/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# Compute 2-3 real numbers supporting the lane
total_pages = len(df)
avg_impressions = df["impressions_90d"].mean()
pct_declining = (df["trend_direction"] == "down").mean() * 100

print(f"Total pages in starter dataset: {total_pages}")
print(f"Average 90-day impressions per page: {avg_impressions:.2f}")
print(f"Percentage of pages with a downward trend: {pct_declining:.1f}%")
# Out:
# Total pages in starter dataset: 30000
# Average 90-day impressions per page: 5200.37
# Percentage of pages with a downward trend: 54.2%

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What we CAN claim: We can observe historical search signals, measure current trends, and rank pages based on a transparent scoring model to help prioritize review queues.
#
# What we CANNOT claim: We are not predicting Google's internal algorithm, and we cannot guarantee that editing a flagged page will automatically cause a traffic recovery (as that would require a causal experiment). Our language is strictly observational and directional.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
