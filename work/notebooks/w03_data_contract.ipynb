# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arisckm/vigilant-system/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# What one row means for your lane: One row represents a unique content item (content_id) for a specific client tracked over a monthly report window.
#
# Which table(s) you'll use: fact_content_daily_performance joined with dim_content.
#
# Which time window: A mid-panel month for iteration (e.g., 2026-03), keeping June 2026 strictly sealed as the test outcome window.
#
# What you'd predict or rank (label or proxy): A binary indicator of whether a page's traffic trend will decline (trend_direction == 'down').
#
# One thing you deliberately exclude: Future performance signals or post-decision outcome metrics that aren't known at the moment the refresh decision is made.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Feature: impressions_90d, clicks_90d, avg_position
#
# Label: is_declining (binary indicator of traffic drop)
#
# Context: content_id, report_date (identifiers to group/track data, not used to predict)
#
# Excluded: future_impressions (excluded because it's a future outcome signal unknown at decision time)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import pandas as pd

# 1. Load your lane's starter dataset slice
url = "https://raw.githubusercontent.com/arisckm/vigilant-system/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# 2. Check row count and grain (One row = One unique web page/content item)
print(f"Total rows (Grain check): {len(df)}")
print(f"Unique pages: {df['content_id'].nunique()}")

# 3. Check data availability with boolean filtering (IS TRUE equivalent)
available_rows = df[df['impressions_90d'].notnull()].shape[0]
print(f"Rows with available impressions data: {available_rows}")

# 4. Show a quick 5-feature frame snippet
features = df[['content_id', 'impressions_90d', 'clicks_90d', 'trend_direction']].head(5)
display(features)
# Out:
# Total rows (Grain check): 30000
# Unique pages: 30000
# Rows with available impressions data: 30000
#              content_id  impressions_90d  clicks_90d trend_direction
# 0  content_304f48230142             3803          29            down
# 1  content_a1fb4e703a9e            15320           7            down
# 2  content_9aa793d4d895            12581          11            down
# 3  content_331d6c4de07b            11751          58          stable
# 4  content_d99b7a2d90ca            19140          24            down

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Named limitation: This dataset excludes external search engine algorithm volatility changes and sudden ranking drops caused by external competitor shifts outside our tracked keywords.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
